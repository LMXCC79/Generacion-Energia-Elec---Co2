# %% [markdown]
# ## ***'EDA' - ENERGIA ELECTRICA NUCLEAR Y GENERACION GASES EFECTO INVERNADERO*** ##

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import sys
import os
sys.path.append('../')

# %%
directorio_actual = os.getcwd()
print (directorio_actual)
print (os.listdir(directorio_actual))
# Out:
# c:\Users\Sandia\Documents\DS_PT_09_2023\Data_Analysis\EDA\src
# ['data', 'doc', 'EDA_Energia_Nuclear_Invernadero.ipynb', 'notebooks', 'utils']

# %%
relativa = 'data/raw/Primary-energy-consumption-from-fossilfuels-nuclear-renewables.csv'
df = pd.read_csv (relativa)

# %%
df
# Out:
#       Entity      Code  Year  Fossil fuels (% sub energy)  \
# 0     Africa       NaN  1965                       94.463
# 1     Africa       NaN  1966                       94.127
# 2     Africa       NaN  1967                       93.920
# 3     Africa       NaN  1968                       93.257
# 4     Africa       NaN  1969                       92.317
# ...      ...       ...   ...                          ...
# 4279   World  OWID_WRL  2015                       85.839
# 4280   World  OWID_WRL  2016                       85.459
# 4281   World  OWID_WRL  2017                       85.123
# 4282   World  OWID_WRL  2018                       84.846
# 4283   World  OWID_WRL  2019                       84.320
#
#       Renewables (% sub energy)  Nuclear (% sub energy)
# 0                         5.537                   0.000
# 1                         5.873                   0.000
# 2                         6.080                   0.000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4284 entries, 0 to 4283
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Entity                       4284 non-null   object
#  1   Code                         4119 non-null   object
#  2   Year                         4284 non-null   int64
#  3   Fossil fuels (% sub energy)  4284 non-null   float64
#  4   Renewables (% sub energy)    4284 non-null   float64
#  5   Nuclear (% sub energy)       4284 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 200.9+ KB

# %%
df.describe()
# Out:
#               Year  Fossil fuels (% sub energy)  Renewables (% sub energy)  \
# count  4284.000000                  4284.000000                4284.000000
# mean   1993.113912                    87.055670                   9.769009
# std      15.678077                    14.866718                  13.166014
# min    1965.000000                    17.162000                   0.000000
# 25%    1980.000000                    81.792250                   1.010500
# 50%    1994.000000                    92.165500                   5.060000
# 75%    2007.000000                    97.951250                  13.185000
# max    2019.000000                   100.000000                  82.835000
#
#        Nuclear (% sub energy)
# count             4284.000000
# mean                 3.126016
# std                  6.639930
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  2.121750
# max                 41.707000

# %%
df.shape
# Out:
# (4284, 6)

# %%
df['Entity'].unique()
# Out:
# array(['Africa', 'Algeria', 'Argentina', 'Australia', 'Austria',
#        'Azerbaijan', 'Bangladesh', 'Belarus', 'Belgium', 'Brazil',
#        'Bulgaria', 'Canada', 'Chile', 'China', 'Colombia', 'Croatia',
#        'Cyprus', 'Czechia', 'Denmark', 'Ecuador', 'Egypt', 'Estonia',
#        'Europe', 'Finland', 'France', 'Germany', 'Greece', 'Hong Kong',
#        'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq',
#        'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Kuwait',
#        'Latvia', 'Lithuania', 'Luxembourg', 'Malaysia', 'Mexico',
#        'Morocco', 'Netherlands', 'New Zealand', 'North America',
#        'North Macedonia', 'Norway', 'Oman', 'Pakistan', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia',
#        'Saudi Arabia', 'Singapore', 'Slovakia', 'Slovenia',
#        'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sweden',
#        'Switzerland', 'Taiwan', 'Thailand', 'Trinidad and Tobago',
# ...

# %%
df.Code.unique().shape
# Out:
# (81,)

# %%
df.Entity.unique().shape
# Out:
# (83,)

# %%
df.isna().sum()/len(df)*100
# Out:
# Entity                         0.000000
# Code                           3.851541
# Year                           0.000000
# Fossil fuels (% sub energy)    0.000000
# Renewables (% sub energy)      0.000000
# Nuclear (% sub energy)         0.000000
# dtype: float64

# %%
df[df['Code'].isna()]
# Out:
#              Entity Code  Year  Fossil fuels (% sub energy)  \
# 0            Africa  NaN  1965                       94.463
# 1            Africa  NaN  1966                       94.127
# 2            Africa  NaN  1967                       93.920
# 3            Africa  NaN  1968                       93.257
# 4            Africa  NaN  1969                       92.317
# ...             ...  ...   ...                          ...
# 2539  North America  NaN  2015                       82.853
# 2540  North America  NaN  2016                       82.146
# 2541  North America  NaN  2017                       81.586
# 2542  North America  NaN  2018                       82.022
# 2543  North America  NaN  2019                       81.710
#
#       Renewables (% sub energy)  Nuclear (% sub energy)
# 0                         5.537                   0.000
# 1                         5.873                   0.000
# 2                         6.080                   0.000
# ...

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Fossil fuels (% sub energy)',
#        'Renewables (% sub energy)', 'Nuclear (% sub energy)'],
#       dtype='object')

# %%
for i in df.select_dtypes(include=object):
    print(f"La cardinalidad de la variable {i} es {(df[i].nunique()/df.shape[0])*100:.2f}%")
# Out:
# La cardinalidad de la variable Entity es 1.94%
# La cardinalidad de la variable Code es 1.87%

# %%
sns.pairplot(df, kind='scatter', hue='Nuclear (% sub energy)',
            plot_kws=dict(s=80, edgecolor='white',linewidth=2.5));
